# %% [markdown]
# ### تعليمات من الصفر لبداية الكويست:
# - لو فلاتر تمام عندك المفروض انك تبدأ بمشروع جديد وتستعمل الكوماند التالي عشان تنشئ المشروع ```flutter create side_quest_app```
# - الحين عليك انك تحمل ملف موجود بالريبو وتحطه داخل المشروع اللي سويته مثل الصوره التاليه:
#
# اسم الملف: assets
#
# ![image.png](attachment:image-2.png)
# - بعد ماتشغل التطبيق الافتراضي لفلاتر لازم تسوي تعديلات بسيطه عشان تقدر تستعمل صور بتطبيقك اول شيء لازم تدخل الملف اللي موضح تحت وتشيل الكومنتس وتغيرها للي تحت زي ماسوينا:
#
# اسم الملف: pubspec.yaml
#
# قبل:![image.png](attachment:image.png)
#
# بعد:![image.png](attachment:image-3.png)

# %% [markdown]
# ### الحين تقدر تحذف محتوى المين كامل بمشروعك الجديد وتبدله بمحتوى المين اللي موجود بالريبو:

# %% [markdown]
# #### Make your main empty -> copy main from this repo -> paste it in your empty main.dart
# ![image.png](attachment:image.png)
